# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

def load_data(data_dir, img_height, img_width):
    images = []
    labels = []
    class_names = os.listdir(data_dir)

    for label in class_names:
        person_dir = os.path.join(data_dir, label)
        if os.path.isdir(person_dir):
            for img_file in os.listdir(person_dir):
                img_path = os.path.join(person_dir, img_file)
                img = load_img(img_path, target_size=(img_height, img_width))
                img_array = img_to_array(img)
                images.append(img_array)
                labels.append(class_names.index(label))  # Use index as label

    return np.array(images), np.array(labels), class_names

def create_model(num_classes):
    model = tf.keras.models.Sequential([
        tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(200, 200, 3)),
        tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
        tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(num_classes, activation='softmax')
    ])
    return model

def train_model():
    img_height, img_width = 200, 200
    data_dir = "D:\\downloads\\Dataset\\dataset" 

    # Load dataset
    images, labels, class_names = load_data(data_dir, img_height, img_width)

    # Normalize images
    images = images / 255.0

    # Convert labels to categorical (one-hot encoding)
    labels = to_categorical(labels, num_classes=len(class_names))

    # Split the dataset into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)

    # Create the model
    model = create_model(num_classes=len(class_names))

    # Compile the model
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

    # Train the model
    history = model.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test))

    # Save the model
    model.save('face_recognition_model.h5')
    print("Model saved as 'face_recognition_model.h5'")

    # Save class names to a file for later use
    with open('class_names.txt', 'w') as f:
        for name in class_names:
            f.write(f"{name}\n")
    print("Class names saved to 'class_names.txt'")


if __name__ == "__main__":
    train_model()
# Out:
# Epoch 1/10
# 3/3 [==============================] - 7s 1s/step - loss: 2.3612 - accuracy: 0.2262 - val_loss: 1.8570 - val_accuracy: 0.2381
# Epoch 2/10
# 3/3 [==============================] - 3s 928ms/step - loss: 1.6101 - accuracy: 0.4167 - val_loss: 1.2372 - val_accuracy: 0.6190
# Epoch 3/10
# 3/3 [==============================] - 8s 4s/step - loss: 0.9636 - accuracy: 0.9405 - val_loss: 0.5903 - val_accuracy: 0.9524
# Epoch 4/10
# 3/3 [==============================] - 4s 1s/step - loss: 0.2606 - accuracy: 1.0000 - val_loss: 0.2426 - val_accuracy: 0.8095
# Epoch 5/10
# 3/3 [==============================] - 4s 1s/step - loss: 0.0431 - accuracy: 1.0000 - val_loss: 0.0868 - val_accuracy: 0.9524
# Epoch 6/10
# 3/3 [==============================] - 3s 1s/step - loss: 0.0216 - accuracy: 0.9881 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 7/10
# 3/3 [==============================] - 3s 1s/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 8/10
# 3/3 [==============================] - 3s 965ms/step - loss: 8.2823e-04 - accuracy: 1.0000 - val_loss: 0.0198 - val_accuracy: 1.0000
# Epoch 9/10
# 3/3 [==============================] - 3s 1s/step - loss: 1.4794e-04 - accuracy: 1.0000 - val_loss: 0.4002 - val_accuracy: 0.9524
# Epoch 10/10
# 3/3 [==============================] - 3s 952ms/step - loss: 0.0126 - accuracy: 0.9881 - val_loss: 3.9538e-04 - val_accuracy: 1.0000
# Model saved as 'face_recognition_model.h5'
# Class names saved to 'class_names.txt'

# %%
img_height, img_width = 200, 200
data_dir = "D:\\downloads\\Dataset\\dataset"  

    # Load dataset
images, labels, class_names = load_data(data_dir, img_height, img_width)

    # Normalize images
images = images / 255.0

    # Convert labels to categorical (one-hot encoding)
labels = to_categorical(labels, num_classes=len(class_names))

    # Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)

    # Create the model
model = create_model(num_classes=len(class_names))

    # Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

    # Train the model
history = model.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test))

    # Print accuracy information
print(f"Training Accuracy: {history.history['accuracy'][-1]*100:.2f}%")
print(f"Validation Accuracy: {history.history['val_accuracy'][-1]*100:.2f}%")
# Out:
# Epoch 1/10
# 3/3 [==============================] - 10s 3s/step - loss: 3.5505 - accuracy: 0.1786 - val_loss: 1.9693 - val_accuracy: 0.4286
# Epoch 2/10
# 3/3 [==============================] - 3s 926ms/step - loss: 1.8406 - accuracy: 0.4405 - val_loss: 1.6321 - val_accuracy: 0.5238
# Epoch 3/10
# 3/3 [==============================] - 3s 934ms/step - loss: 1.4483 - accuracy: 0.6429 - val_loss: 1.2348 - val_accuracy: 0.4762
# Epoch 4/10
# 3/3 [==============================] - 3s 923ms/step - loss: 0.8218 - accuracy: 0.8571 - val_loss: 0.5792 - val_accuracy: 0.9524
# Epoch 5/10
# 3/3 [==============================] - 3s 951ms/step - loss: 0.2724 - accuracy: 0.9881 - val_loss: 0.4374 - val_accuracy: 0.8095
# Epoch 6/10
# 3/3 [==============================] - 3s 996ms/step - loss: 0.1712 - accuracy: 0.9524 - val_loss: 0.1424 - val_accuracy: 0.9524
# Epoch 7/10
# 3/3 [==============================] - 3s 949ms/step - loss: 0.0250 - accuracy: 1.0000 - val_loss: 0.6597 - val_accuracy: 0.8095
# Epoch 8/10
# 3/3 [==============================] - 3s 933ms/step - loss: 0.0870 - accuracy: 0.9643 - val_loss: 0.2851 - val_accuracy: 0.9524
# Epoch 9/10
# 3/3 [==============================] - 3s 927ms/step - loss: 0.0392 - accuracy: 0.9881 - val_loss: 0.4036 - val_accuracy: 0.9048
# Epoch 10/10
# 3/3 [==============================] - 3s 964ms/step - loss: 0.0150 - accuracy: 0.9881 - val_loss: 0.1065 - val_accuracy: 0.9524
# Training Accuracy: 98.81%
# Validation Accuracy: 95.24%
